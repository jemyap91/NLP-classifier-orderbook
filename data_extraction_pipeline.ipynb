# %%
# pip install ollama pandas openpyxl
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import ollama
import os
import re
from typing import Dict, List, Optional
import pandas as pd
import data_extraction

# %%
raw_data = data_extraction.extract_all("data")
# Out:
#                                       project_title  \
# 0      132027 - Moorabbin Hospital - Carpark Conver
# 1            130348 - New Epping - Medical Building
# 2                     130524 - RWH Rapid Access Hub
# 3          131450 - Monash Medical Centre Tower Exp
# 4               131568 - RWH Level 3 Birthing Suite
# ...                                             ...
# 17058                                    EKU Energy
# 17059                        STT (Peer review)_PO#1
# 17060                               Air Trunk (MEP)
# 17061                                     VDC KIX12
# 17062                              EV (Peer review)
#
#                     project_type                                client  \
# 0      Community & Institutional  AUVICKAN - Kane Construction Pty Ltd
# 1      Community & Institutional          AUVICRIVE - Riverlee Pty Ltd
# 2      Community & Institutional        GRAY981 - GRAY PUKSAND PTY LTD
# ...

# %%
columns = ["project_title", "client", "project_type"]
df = raw_data[columns].copy()
df["project_title_and_client"] = df['project_title'] + " " + df['client']
df
# Out:
#                                       project_title  \
# 0      132027 - Moorabbin Hospital - Carpark Conver
# 1            130348 - New Epping - Medical Building
# 2                     130524 - RWH Rapid Access Hub
# 3          131450 - Monash Medical Centre Tower Exp
# 4               131568 - RWH Level 3 Birthing Suite
# ...                                             ...
# 17058                                    EKU Energy
# 17059                        STT (Peer review)_PO#1
# 17060                               Air Trunk (MEP)
# 17061                                     VDC KIX12
# 17062                              EV (Peer review)
#
#                                      client               project_type  \
# 0      AUVICKAN - Kane Construction Pty Ltd  Community & Institutional
# 1              AUVICRIVE - Riverlee Pty Ltd  Community & Institutional
# 2            GRAY981 - GRAY PUKSAND PTY LTD  Community & Institutional
# ...

# %%
unique_categories = df['project_type'].unique().tolist()
unique_categories = [e for e in unique_categories if e not in (None, "nan", "Cancelled")]
unique_categories
# Out:
# ['Community & Institutional',
#  'Residential',
#  'Industrial',
#  'Commercial',
#  'Hotel & Resort',
#  'Infrastructure',
#  'Aviation',
#  'Mixed Use Development',
#  'Water & Environment',
#  'Mining & Resources',
#  'commercial',
#  'residential',
#  'Healthcare',
#  'Data Center',
#  'Community & Instituitional',
#  'Institutional']
